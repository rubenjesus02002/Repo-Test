# %% [markdown]
# <a href="https://colab.research.google.com/github/rubenjesus02002/Repo-Test/blob/main/Google%20Colab%20Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-storage-blob
# !pip install pymongo
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.25.1-py3-none-any.whl.metadata (26 kB)
# Collecting azure-core>=1.30.0 (from azure-storage-blob)
#   Downloading azure_core-1.35.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob) (43.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob) (4.14.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure-storage-blob) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2025.6.15)
# Downloading azure_storage_blob-12.25.1-py3-none-any.whl (406 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.0/407.0 kB 10.3 MB/s eta 0:00:00
# Downloading azure_core-1.35.0-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 14.4 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.35.0 azure-storage-blob-12.25.1 isodate-0.7.2
# Collecting pymongo
#   Downloading pymongo-4.13.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.13.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.7 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.13.2

# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

# %%
# read the config file that is json
import json
with open('config.json') as config_file:
  config = json.load(config_file)

# read information about source
SOURCE_CONNECTION_STRING = config['SOURCE_CONNECTION_STRING']
SOURCE_CONTAINER_NAME = config['SOURCE_CONTAINER_NAME']
SOURCE_FILE_NAME = config['SOURCE_FILE_NAME']

DESTINATION_CONNECTION_STRING = config['DESTINATION_CONNECTION_STRING']
DESTINATION_CONTAINER_NAME = config['DESTINATION_CONTAINER_NAME']
DESTINATION_FILE_NAME = config['DESTINATION_FILE_NAME']

# %%
# Assuming you have SOURCE_CONNECTION_STRING, SOURCE_CONTAINER_NAME,
# DESTINATION_CONNECTION_STRING, and DESTINATION_CONTAINER_NAME defined from your config files.

# Instantiate BlobServiceClient for the source
source_blob_service_client = BlobServiceClient.from_connection_string(SOURCE_CONNECTION_STRING)

# Get a client for the source container
source_container_client = source_blob_service_client.get_container_client(SOURCE_CONTAINER_NAME)

# List all blobs in the source container
blob_list = source_container_client.list_blobs()

# Loop through each blob in the source container
for blob in blob_list:
    print(f"Processing blob: {blob.name}")
    # Download the blob to a local file
    source_blob_name = blob.name
    # take only every after the forward slash
    local_file_name = source_blob_name.split('/')[-1]

    print(f"Downloading blob: {source_blob_name}")

    # Download the blob to a local file
    source_blob_client = source_blob_service_client.get_blob_client(container=SOURCE_CONTAINER_NAME, blob=source_blob_name)
    with open(local_file_name, "wb") as my_blob:
        download_stream = source_blob_client.download_blob()
        my_blob.write(download_stream.readall())

    print(f"Uploading blob: {source_blob_name}")

    # Upload the local file to the destination container
    destination_blob_service_client = BlobServiceClient.from_connection_string(DESTINATION_CONNECTION_STRING)
    destination_container_client = destination_blob_service_client.get_container_client(DESTINATION_CONTAINER_NAME)

    # You can use the same blob name or define a new one for the destination
    # destination_blob_name = source_blob_name
    with open(local_file_name, "rb") as data:
        destination_blob_client = destination_container_client.upload_blob(name=source_blob_name, data=data, overwrite=True)

    print(f"Uploaded blob '{source_blob_name}' to destination as '{source_blob_name}'.")

    # Optional: Clean up the local file
    import os
    os.remove(local_file_name)
    print(f"Removed local file: {local_file_name}")

print("Finished processing all blobs.")
# Out:
# Processing blob: 2024-12-02/XCBT_CommodityAgriculture.json
# Downloading blob: 2024-12-02/XCBT_CommodityAgriculture.json
# Uploading blob: 2024-12-02/XCBT_CommodityAgriculture.json
# Uploaded blob '2024-12-02/XCBT_CommodityAgriculture.json' to destination as '2024-12-02/XCBT_CommodityAgriculture.json'.
# Removed local file: XCBT_CommodityAgriculture.json
# Processing blob: 2024-12-02/XCBT_Currency.json
# Downloading blob: 2024-12-02/XCBT_Currency.json
# Uploading blob: 2024-12-02/XCBT_Currency.json
# Uploaded blob '2024-12-02/XCBT_Currency.json' to destination as '2024-12-02/XCBT_Currency.json'.
# Removed local file: XCBT_Currency.json
# Processing blob: 2024-12-02/XCEC_CommodityAgriculture.json
# Downloading blob: 2024-12-02/XCEC_CommodityAgriculture.json
# Uploading blob: 2024-12-02/XCEC_CommodityAgriculture.json
# Uploaded blob '2024-12-02/XCEC_CommodityAgriculture.json' to destination as '2024-12-02/XCEC_CommodityAgriculture.json'.
# Removed local file: XCEC_CommodityAgriculture.json
# Processing blob: 2024-12-02/XCEC_Currency.json
# Downloading blob: 2024-12-02/XCEC_Currency.json
# Uploading blob: 2024-12-02/XCEC_Currency.json
# Uploaded blob '2024-12-02/XCEC_Currency.json' to destination as '2024-12-02/XCEC_Currency.json'.
# Removed local file: XCEC_Currency.json
# Processing blob: 2024-12-02/XCME_CommodityAgriculture.json
# Downloading blob: 2024-12-02/XCME_CommodityAgriculture.json
# Uploading blob: 2024-12-02/XCME_CommodityAgriculture.json
# Uploaded blob '2024-12-02/XCME_CommodityAgriculture.json' to destination as '2024-12-02/XCME_CommodityAgriculture.json'.
# Removed local file: XCME_CommodityAgriculture.json
# Processing blob: 2024-12-02/XCME_Currency.json
# Downloading blob: 2024-12-02/XCME_Currency.json
# Uploading blob: 2024-12-02/XCME_Currency.json
# Uploaded blob '2024-12-02/XCME_Currency.json' to destination as '2024-12-02/XCME_Currency.json'.
# Removed local file: XCME_Currency.json
# Processing blob: 2024-12-02/XNYM_CommodityAgriculture.json
# Downloading blob: 2024-12-02/XNYM_CommodityAgriculture.json
# Uploading blob: 2024-12-02/XNYM_CommodityAgriculture.json
# Uploaded blob '2024-12-02/XNYM_CommodityAgriculture.json' to destination as '2024-12-02/XNYM_CommodityAgriculture.json'.
# Removed local file: XNYM_CommodityAgriculture.json
# Processing blob: 2024-12-02/XNYM_Currency.json
# Downloading blob: 2024-12-02/XNYM_Currency.json
# Uploading blob: 2024-12-02/XNYM_Currency.json
# Uploaded blob '2024-12-02/XNYM_Currency.json' to destination as '2024-12-02/XNYM_Currency.json'.
# Removed local file: XNYM_Currency.json
# Processing blob: 2024-12-03/XCBT_CommodityAgriculture.json
# Downloading blob: 2024-12-03/XCBT_CommodityAgriculture.json
# Uploading blob: 2024-12-03/XCBT_CommodityAgriculture.json
# Uploaded blob '2024-12-03/XCBT_CommodityAgriculture.json' to destination as '2024-12-03/XCBT_CommodityAgriculture.json'.
# Removed local file: XCBT_CommodityAgriculture.json
# Processing blob: 2024-12-03/XCBT_Currency.json
# Downloading blob: 2024-12-03/XCBT_Currency.json
# Uploading blob: 2024-12-03/XCBT_Currency.json
# Uploaded blob '2024-12-03/XCBT_Currency.json' to destination as '2024-12-03/XCBT_Currency.json'.
# Removed local file: XCBT_Currency.json
# Processing blob: 2024-12-03/XCEC_CommodityAgriculture.json
# Downloading blob: 2024-12-03/XCEC_CommodityAgriculture.json
# Uploading blob: 2024-12-03/XCEC_CommodityAgriculture.json
# Uploaded blob '2024-12-03/XCEC_CommodityAgriculture.json' to destination as '2024-12-03/XCEC_CommodityAgriculture.json'.
# Removed local file: XCEC_CommodityAgriculture.json
# Processing blob: 2024-12-03/XCEC_Currency.json
# Downloading blob: 2024-12-03/XCEC_Currency.json
# Uploading blob: 2024-12-03/XCEC_Currency.json
# Uploaded blob '2024-12-03/XCEC_Currency.json' to destination as '2024-12-03/XCEC_Currency.json'.
# Removed local file: XCEC_Currency.json
# Processing blob: 2024-12-03/XCME_CommodityAgriculture.json
# Downloading blob: 2024-12-03/XCME_CommodityAgriculture.json
# Uploading blob: 2024-12-03/XCME_CommodityAgriculture.json
# Uploaded blob '2024-12-03/XCME_CommodityAgriculture.json' to destination as '2024-12-03/XCME_CommodityAgriculture.json'.
# Removed local file: XCME_CommodityAgriculture.json
# Processing blob: 2024-12-03/XCME_Currency.json
# Downloading blob: 2024-12-03/XCME_Currency.json
# Uploading blob: 2024-12-03/XCME_Currency.json
# Uploaded blob '2024-12-03/XCME_Currency.json' to destination as '2024-12-03/XCME_Currency.json'.
# Removed local file: XCME_Currency.json
# Processing blob: 2024-12-03/XNYM_CommodityAgriculture.json
# Downloading blob: 2024-12-03/XNYM_CommodityAgriculture.json
# Uploading blob: 2024-12-03/XNYM_CommodityAgriculture.json
# Uploaded blob '2024-12-03/XNYM_CommodityAgriculture.json' to destination as '2024-12-03/XNYM_CommodityAgriculture.json'.
# Removed local file: XNYM_CommodityAgriculture.json
# Processing blob: 2024-12-03/XNYM_Currency.json
# Downloading blob: 2024-12-03/XNYM_Currency.json
# Uploading blob: 2024-12-03/XNYM_Currency.json
# Uploaded blob '2024-12-03/XNYM_Currency.json' to destination as '2024-12-03/XNYM_Currency.json'.
# Removed local file: XNYM_Currency.json
# Processing blob: 2024-12-04/XCBT_CommodityAgriculture.json
# Downloading blob: 2024-12-04/XCBT_CommodityAgriculture.json
# Uploading blob: 2024-12-04/XCBT_CommodityAgriculture.json
# Uploaded blob '2024-12-04/XCBT_CommodityAgriculture.json' to destination as '2024-12-04/XCBT_CommodityAgriculture.json'.
# Removed local file: XCBT_CommodityAgriculture.json
# Processing blob: 2024-12-04/XCBT_Currency.json
# Downloading blob: 2024-12-04/XCBT_Currency.json
# Uploading blob: 2024-12-04/XCBT_Currency.json
# Uploaded blob '2024-12-04/XCBT_Currency.json' to destination as '2024-12-04/XCBT_Currency.json'.
# Removed local file: XCBT_Currency.json
# Processing blob: 2024-12-04/XCEC_CommodityAgriculture.json
# Downloading blob: 2024-12-04/XCEC_CommodityAgriculture.json
# Uploading blob: 2024-12-04/XCEC_CommodityAgriculture.json
# Uploaded blob '2024-12-04/XCEC_CommodityAgriculture.json' to destination as '2024-12-04/XCEC_CommodityAgriculture.json'.
# Removed local file: XCEC_CommodityAgriculture.json
# Processing blob: 2024-12-04/XCEC_Currency.json
# Downloading blob: 2024-12-04/XCEC_Currency.json
# Uploading blob: 2024-12-04/XCEC_Currency.json
# Uploaded blob '2024-12-04/XCEC_Currency.json' to destination as '2024-12-04/XCEC_Currency.json'.
# Removed local file: XCEC_Currency.json
# Processing blob: 2024-12-04/XCME_CommodityAgriculture.json
# Downloading blob: 2024-12-04/XCME_CommodityAgriculture.json
# Uploading blob: 2024-12-04/XCME_CommodityAgriculture.json
# Uploaded blob '2024-12-04/XCME_CommodityAgriculture.json' to destination as '2024-12-04/XCME_CommodityAgriculture.json'.
# Removed local file: XCME_CommodityAgriculture.json
# Processing blob: 2024-12-04/XCME_Currency.json
# Downloading blob: 2024-12-04/XCME_Currency.json
# Uploading blob: 2024-12-04/XCME_Currency.json
# Uploaded blob '2024-12-04/XCME_Currency.json' to destination as '2024-12-04/XCME_Currency.json'.
# Removed local file: XCME_Currency.json
# Processing blob: 2024-12-04/XNYM_CommodityAgriculture.json
# Downloading blob: 2024-12-04/XNYM_CommodityAgriculture.json
# Uploading blob: 2024-12-04/XNYM_CommodityAgriculture.json
# Uploaded blob '2024-12-04/XNYM_CommodityAgriculture.json' to destination as '2024-12-04/XNYM_CommodityAgriculture.json'.
# Removed local file: XNYM_CommodityAgriculture.json
# Processing blob: 2024-12-04/XNYM_Currency.json
# Downloading blob: 2024-12-04/XNYM_Currency.json
# Uploading blob: 2024-12-04/XNYM_Currency.json
# Uploaded blob '2024-12-04/XNYM_Currency.json' to destination as '2024-12-04/XNYM_Currency.json'.
# Removed local file: XNYM_Currency.json
# Processing blob: 2024-12-05/XCBT_CommodityAgriculture.json
# Downloading blob: 2024-12-05/XCBT_CommodityAgriculture.json
# Uploading blob: 2024-12-05/XCBT_CommodityAgriculture.json
# Uploaded blob '2024-12-05/XCBT_CommodityAgriculture.json' to destination as '2024-12-05/XCBT_CommodityAgriculture.json'.
# Removed local file: XCBT_CommodityAgriculture.json
# Processing blob: 2024-12-05/XCBT_Currency.json
# Downloading blob: 2024-12-05/XCBT_Currency.json
# Uploading blob: 2024-12-05/XCBT_Currency.json
# Uploaded blob '2024-12-05/XCBT_Currency.json' to destination as '2024-12-05/XCBT_Currency.json'.
# Removed local file: XCBT_Currency.json
# Processing blob: 2024-12-05/XCEC_CommodityAgriculture.json
# Downloading blob: 2024-12-05/XCEC_CommodityAgriculture.json
# Uploading blob: 2024-12-05/XCEC_CommodityAgriculture.json
# Uploaded blob '2024-12-05/XCEC_CommodityAgriculture.json' to destination as '2024-12-05/XCEC_CommodityAgriculture.json'.
# Removed local file: XCEC_CommodityAgriculture.json
# Processing blob: 2024-12-05/XCEC_Currency.json
# Downloading blob: 2024-12-05/XCEC_Currency.json
# Uploading blob: 2024-12-05/XCEC_Currency.json
# Uploaded blob '2024-12-05/XCEC_Currency.json' to destination as '2024-12-05/XCEC_Currency.json'.
# Removed local file: XCEC_Currency.json
# Processing blob: 2024-12-05/XCME_CommodityAgriculture.json
# Downloading blob: 2024-12-05/XCME_CommodityAgriculture.json
# Uploading blob: 2024-12-05/XCME_CommodityAgriculture.json
# Uploaded blob '2024-12-05/XCME_CommodityAgriculture.json' to destination as '2024-12-05/XCME_CommodityAgriculture.json'.
# Removed local file: XCME_CommodityAgriculture.json
# Processing blob: 2024-12-05/XCME_Currency.json
# Downloading blob: 2024-12-05/XCME_Currency.json
